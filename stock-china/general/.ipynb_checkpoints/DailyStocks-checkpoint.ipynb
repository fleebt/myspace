# %%
##涨跌停计算器

##### 参数：价格 ######
currentPrice = 14.53
###################

def calculateLimitPrice(price):
    lowRate = 0.9
    highRate = 1.1
    smallNum = 0.00001
    low = round(price*lowRate + smallNum, 2)
    high = round(price*highRate + smallNum, 2)
    return [low, high]

print(calculateLimitPrice(currentPrice))
# Out:
# [13.08, 15.98]

# %%
###两市成交额&上证综指日K图
import tushare as ts
import numpy as np
from pandas import DataFrame
import time
from pyecharts import Bar, Kline, Line, Grid

peroid = 30 ###分析的交易日天数

try:
    settingFile = open('/data/stock-setting.txt', 'r')
    settings = settingFile.read()
    token = settings.split()[0]
    secretUrl = settings.split()[1]
    settingFile.close()
except IOError:
    print('File is not accessible.')
pro = ts.pro_api(token)

#################函数#####################
def calculateLimitPrice(price):
    lowRate = 0.9
    highRate = 1.1
    smallNum = 0.00001
    low = round(price*lowRate + smallNum, 2)
    high = round(price*highRate + smallNum, 2)
    return [low, high]

def isLimitHighPrice(close, pre_close):
    limitHighPrice = calculateLimitPrice(pre_close)
    if limitHighPrice[1] == close:
        return True
    else:
        return False
def belongTo(close, pre_close):
    var = (close - pre_close) / pre_close
    if isLimitHighPrice(close, pre_close):
        return 6
    elif var >= 0.07:
        return 5
    elif var >= 0.03:
        return 4
    elif var >= 0:
        return 3
    elif var > -0.03:
        return 2
    elif var >-0.07:
        return 1
    else:
        return 0    
#################################################

###获取交易日历
currentDate = time.strftime('%Y%m%d',time.localtime(time.time()))
calendar = pro.trade_cal(is_open = 1, end_date = currentDate, fields = 'cal_date')
calendarCut = calendar[-peroid:]
startDate = calendarCut.iloc[0, 0]
endDate = calendarCut.iloc[peroid-1, 0]

###获取日K及成交额
szCode = '399001.SZ'
shCode = '000001.SH'
indexDaily = pro.index_daily(ts_code = shCode, start_date = startDate, end_date = endDate, fields = 'ts_code, trade_date, open, close, low, high, pre_close, pct_chg, amount')
szIndexDaily = pro.index_daily(ts_code = szCode, start_date = startDate, end_date = endDate, fields = 'ts_code, trade_date, amount')

dailyVolume = np.trunc((indexDaily.amount.values +  szIndexDaily.amount.values) / 100000)

kData = np.array([indexDaily.open.values, indexDaily.close.values, indexDaily.low.values, indexDaily.high.values])
kData = kData.transpose().tolist()[::-1]
date = indexDaily.trade_date.values.tolist()[::-1]

###分析涨停分布
resultPercent = []
twoDayLimitUpStocks = []
for i in range(0, len(date)-1):
    today = date[i]
    nextDay = date[i+1]
    dailyInfo = pro.daily(trade_date = today, fields = 'ts_code, close, pre_close')
    nextDayInfo = pro.daily(trade_date = nextDay, fields = 'ts_code, close, pre_close')
    
    nextDayInfo.index = nextDayInfo.ts_code
    stocks = []
    percent = [0, 0, 0, 0, 0, 0, 0]
    for j in range(0, dailyInfo.shape[0]):    
        if isLimitHighPrice(dailyInfo.iloc[j, 1], dailyInfo.iloc[j, 2]):
            code = dailyInfo.iloc[j, 0]
            stocks.append(code)
    
    for j in range(0, len(stocks)):
        code = stocks[j]
        if code in nextDayInfo.index:
            info = nextDayInfo.loc[code]
            close = info[1]
            pre_close = info[2]
            catagory = belongTo(close, pre_close)
            percent[catagory] = percent[catagory] + 1
            if i == len(date) - 2 and catagory == 6:
                twoDayLimitUpStocks.append(code)
    resultPercent.append(percent)
print('success')
# Out:
# success

# %%
bar = Bar("涨停次日涨幅分布图", title_top="50%")
xLabel = date[0:len(date)-1]
catagory = ['[-10%, -7%]', '(-7%, -3%]', '(-3%, 0%)', '[0%, 3%)', '[3%, 7%)', '[7%, 10%)', '连板']
for i in range(0, len(catagory)):
    count = []
    for percent in resultPercent:
        count.append(percent[i])
    bar.add(catagory[i], xLabel, count, is_stack=True, legend_top = '93%', legend_bottom = '0%')
bar    


barAmount = Bar("两市成交额(/亿)", title_top="25%")
barAmount.add("", date, dailyVolume[::-1], is_datazoom_show=True, mark_point=["max", "min"])

kline = Kline("上证综指 日K")
kline.add("", date, kData, is_datazoom_show=True, datazoom_xaxis_index=[0, 1, 2],  
          tooltip_formatter = "{c}", tooltip_trigger = "item", tooltip_axispointer_type = "cross")
grid = Grid(width=1000, height=700)
grid.add(kline, grid_bottom="80%")
grid.add(barAmount, grid_top="30%", grid_bottom="55%")
grid.add(bar, grid_top="55%", grid_bottom = '10%')

grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="db1b1997c70147b498b4bea3fdcf150e" style="width:1000px;height:700px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_db1b1997c70147b498b4bea3fdcf150e = echarts.init(document.getElementById('db1b1997c70147b498b4bea3fdcf150e'), 'light', {renderer: 'canvas'});
#
# var option_db1b1997c70147b498b4bea3fdcf150e = {
#     "title": [
#         {
#             "text": "\u4e0a\u8bc1\u7efc\u6307 \u65e5K",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         },
#         {
#             "text": "\u4e24\u5e02\u6210\u4ea4\u989d(/\u4ebf)",
#             "left": "auto",
#             "top": "25%",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         },
#         {
#             "text": "\u6da8\u505c\u6b21\u65e5\u6da8\u5e45\u5206\u5e03\u56fe",
#             "left": "auto",
#             "top": "50%",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4087151,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "formatter": "{c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "candlestick",
#             "data": [
#                 [
#                     3038.3362,
#                     2969.8614,
#                     2969.5815,
#                     3075.0461
#                 ],
#                 [
#                     2969.0802,
#                     3026.9925,
#                     2963.5834,
#                     3028.2543
#                 ],
#                 [
#                     3049.0844,
#                     3060.3073,
#                     3029.8999,
#                     3093.3913
#                 ],
#                 [
#                     3062.3267,
#                     3026.9513,
#                     3013.9319,
#                     3065.2884
#                 ],
#                 [
#                     3013.597,
#                     2990.685,
#                     2968.8237,
#                     3041.1557
#                 ],
#                 [
#                     3000.8789,
#                     3021.7512,
#                     2999.4317,
#                     3048.1212
#                 ],
#                 [
#                     3027.8012,
#                     3096.4176,
#                     3009.5071,
#                     3096.4176
#                 ],
#                 [
#                     3099.8971,
#                     3090.975,
#                     3076.3627,
#                     3113.4325
#                 ],
#                 [
#                     3084.1704,
#                     3090.6403,
#                     3053.4519,
#                     3102.5203
#                 ],
#                 [
#                     3094.1247,
#                     3101.455,
#                     3086.85,
#                     3125.0192
#                 ],
#                 [
#                     3100.7264,
#                     3104.1487,
#                     3064.884,
#                     3107.2754
#                 ],
#                 [
#                     3058.8016,
#                     3043.0313,
#                     3041.9504,
#                     3086.9961
#                 ],
#                 [
#                     3057.559,
#                     2997.0954,
#                     2988.4905,
#                     3062.6896
#                 ],
#                 [
#                     3012.2573,
#                     3022.7196,
#                     2987.7717,
#                     3022.7623
#                 ],
#                 [
#                     3009.7988,
#                     2994.9434,
#                     2991.7789,
#                     3025.7789
#                 ],
#                 [
#                     3000.6783,
#                     3090.758,
#                     2999.9866,
#                     3093.0329
#                 ],
#                 [
#                     3111.6619,
#                     3170.361,
#                     3111.6619,
#                     3176.6221
#                 ],
#                 [
#                     3183.2736,
#                     3176.8227,
#                     3164.9066,
#                     3193.2717
#                 ],
#                 [
#                     3159.1468,
#                     3216.2952,
#                     3152.3319,
#                     3219.2564
#                 ],
#                 [
#                     3233.6886,
#                     3246.5714,
#                     3216.8545,
#                     3254.1401
#                 ],
#                 [
#                     3271.2722,
#                     3244.8103,
#                     3210.5151,
#                     3288.4531
#                 ],
#                 [
#                     3240.3938,
#                     3239.6639,
#                     3215.7048,
#                     3251.6458
#                 ],
#                 [
#                     3224.6454,
#                     3241.9299,
#                     3204.8785,
#                     3264.7778
#                 ],
#                 [
#                     3241.5474,
#                     3189.9619,
#                     3185.546,
#                     3254.1259
#                 ],
#                 [
#                     3184.8595,
#                     3188.6256,
#                     3168.0421,
#                     3199.278
#                 ],
#                 [
#                     3233.4583,
#                     3177.7866,
#                     3177.2698,
#                     3253.9763
#                 ],
#                 [
#                     3164.3969,
#                     3253.5978,
#                     3153.2062,
#                     3253.5978
#                 ],
#                 [
#                     3250.1518,
#                     3263.1179,
#                     3239.8048,
#                     3275.3335
#                 ],
#                 [
#                     3261.0742,
#                     3250.2012,
#                     3241.8257,
#                     3271.3878
#                 ]
#             ],
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4087151,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "bar",
#             "data": [
#                 11841.0,
#                 9444.0,
#                 11370.0,
#                 10512.0,
#                 8125.0,
#                 7506.0,
#                 8326.0,
#                 7756.0,
#                 7799.0,
#                 8859.0,
#                 8019.0,
#                 8193.0,
#                 7683.0,
#                 6647.0,
#                 6636.0,
#                 8362.0,
#                 10439.0,
#                 10384.0,
#                 9333.0,
#                 10049.0,
#                 10670.0,
#                 8401.0,
#                 8989.0,
#                 8173.0,
#                 6571.0,
#                 7757.0,
#                 7910.0,
#                 8301.0,
#                 7534.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {

# %%
###每日涨停统计（不考虑ST股）
import tushare as ts
import numpy as np
from pandas import DataFrame
import time


peroid = 30 #涨停统计周期

try:
    settingFile = open('/data/stock-setting.txt', 'r')
    settings = settingFile.read()
    token = settings.split()[0]
    secretUrl = settings.split()[1]
    settingFile.close()
except IOError:
    print('File is not accessible.')
pro = ts.pro_api(token)


###获取交易日历
currentDate = time.strftime('%Y%m%d',time.localtime(time.time()))
calendar = pro.trade_cal(is_open = 1, end_date = currentDate, fields = 'cal_date')
calendarCut = calendar[-peroid:]
startDate = calendarCut.iloc[0, 0]
endDate = calendarCut.iloc[peroid-1, 0]

dailyInfo = pro.daily(trade_date = endDate, fields = 'ts_code, close, pre_close')
shape = dailyInfo.shape

def calculateLimitPrice(price):
    lowRate = 0.9
    highRate = 1.1
    smallNum = 0.00001
    low = round(price*lowRate + smallNum, 2)
    high = round(price*highRate + smallNum, 2)
    return [low, high]

def isLimitHighPrice(close, pre_close):
    limitHighPrice = calculateLimitPrice(pre_close)
    if limitHighPrice[1] == close:
        return True
    else:
        return False

newShare = pro.new_share(start_date= startDate, end_date=endDate, fields = 'ts_code, name, issue_date, price')
    
stocks = DataFrame([], columns=['code', 'name', 'num', 'new'])
for i in range(0, shape[0]):    
    if isLimitHighPrice(dailyInfo.iloc[i, 1], dailyInfo.iloc[i, 2]):
        code = dailyInfo.iloc[i, 0]
        ###获取股票名称
        nameHistory = pro.namechange(ts_code = code, fields='name')
        name = nameHistory.iloc[0, 0]
        
        ###获取连板数
        recentTrade = pro.daily(ts_code = code, start_date=startDate, end_date=endDate, fields = 'trade_date, close, pre_close, vol')
        count = peroid
        for j in range(0, len(recentTrade)):
            if isLimitHighPrice(recentTrade.iloc[j, 1], recentTrade.iloc[j, 2]) == 0:
                count = j
                break
                
        ###查询是否为近30个交易日内发行的新股
        newState = 1  ## 新股0，非新股1
        if code in newShare.ts_code.values:
            newState = 0
        stocks = stocks.append({'code':code,'name':name, 'num':count, 'new':newState}, ignore_index = True)  
        
sortedStocks = stocks.sort_values(by = ['new', 'num'], ascending = False)
oldStock = sortedStocks[sortedStocks.new > 0.0001]
maxNum = max(oldStock.num.values)
count = 0
for i in range(maxNum, 1, -1):
    stockNames = oldStock[oldStock.num == i].name.values
    if len(stockNames) > 0:
        print(str(i) + '板共' + str(len(stockNames)) + '个: ' + str(stockNames))
        count = count + len(stockNames)
print('\n' + endDate + '的连板股票共' + str(count) +'个, 涨停股票共' + str(len(stocks)) + '个' )
# Out:
# 9板共1个: ['置信电气']
# 5板共2个: ['方盛制药' '东方能源']
# 4板共1个: ['仁智股份']
# 3板共3个: ['东方电气' '东风科技' '保税科技']
# 2板共10个: ['民生控股' '银星能源' '永悦科技' '华体科技' '上海雅仕' '东风汽车' '苏美达' '林海股份' '凯恩股份' '富临运业']
#
# 20190412的连板股票共17个, 涨停股票共51个

# %%
###涨停跟踪
import tushare as ts
import numpy as np
from pandas import DataFrame
from pyecharts import Bar
import time

peroid = 20

try:
    settingFile = open('/data/stock-setting.txt', 'r')
    settings = settingFile.read()
    token = settings.split()[0]
    secretUrl = settings.split()[1]
    settingFile.close()
except IOError:
    print('File is not accessible.')
pro = ts.pro_api(token)

################函数############################
def calculateLimitPrice(price):
    lowRate = 0.9
    highRate = 1.1
    smallNum = 0.00001
    low = round(price*lowRate + smallNum, 2)
    high = round(price*highRate + smallNum, 2)
    return [low, high]

def isLimitHighPrice(close, pre_close):
    limitHighPrice = calculateLimitPrice(pre_close)
    if limitHighPrice[1] == close:
        return True
    else:
        return False
def belongTo(close, pre_close):
    var = (close - pre_close) / pre_close
    if isLimitHighPrice(close, pre_close):
        return 6
    elif var >= 0.07:
        return 5
    elif var >= 0.03:
        return 4
    elif var >= 0:
        return 3
    elif var > -0.03:
        return 2
    elif var >-0.07:
        return 1
    else:
        return 0    
#################################################

###获取交易日历
currentDate = time.strftime('%Y%m%d',time.localtime(time.time()))
calendar = pro.trade_cal(is_open = 1, end_date = currentDate, fields = 'cal_date')
calendarCut = calendar[-peroid:]
startDate = calendarCut.iloc[0, 0]
endDate = calendarCut.iloc[peroid-1, 0]
date = calendarCut.iloc[0: peroid, 0].values
 
###获取涨幅分布
resultPercent = []
twoDayLimitUpStocks = []
for i in range(0, len(date)-1):
    today = date[i]
    nextDay = date[i+1]
    dailyInfo = pro.daily(trade_date = today, fields = 'ts_code, close, pre_close')
    nextDayInfo = pro.daily(trade_date = nextDay, fields = 'ts_code, close, pre_close')
    
    nextDayInfo.index = nextDayInfo.ts_code
    stocks = []
    percent = [0, 0, 0, 0, 0, 0, 0]
    for j in range(0, dailyInfo.shape[0]):    
        if isLimitHighPrice(dailyInfo.iloc[j, 1], dailyInfo.iloc[j, 2]):
            code = dailyInfo.iloc[j, 0]
            stocks.append(code)
    
    for j in range(0, len(stocks)):
        code = stocks[j]
        if code in nextDayInfo.index:
            info = nextDayInfo.loc[code]
            close = info[1]
            pre_close = info[2]
            catagory = belongTo(close, pre_close)
            percent[catagory] = percent[catagory] + 1
            if i == len(date) - 2 and catagory == 6:
                twoDayLimitUpStocks.append(code)
    resultPercent.append(percent)

###绘制涨停次日涨幅分布图
bar = Bar("涨停次日涨幅分布图")
xLabel = date[0:len(date)-1]
catagory = ['[-10%, -7%]', '(-7%, -3%]', '(-3%, 0%)', '[0%, 3%)', '[3%, 7%)', '[7%, 10%)', '连板']
for i in range(0, len(catagory)):
    count = []
    for percent in resultPercent:
        count.append(percent[i])
    bar.add(catagory[i], xLabel, count, is_stack=True, legend_top = 'bottom')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="decc0fd4edc64339b8cb469485cef9e2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_decc0fd4edc64339b8cb469485cef9e2 = echarts.init(document.getElementById('decc0fd4edc64339b8cb469485cef9e2'), 'light', {renderer: 'canvas'});
#
# var option_decc0fd4edc64339b8cb469485cef9e2 = {
#     "title": [
#         {
#             "text": "\u6da8\u505c\u6b21\u65e5\u6da8\u5e45\u5206\u5e03\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2147248,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "[-10%, -7%]",
#             "data": [
#                 67,
#                 4,
#                 1,
#                 30,
#                 28,
#                 0,
#                 3,
#                 1,
#                 0,
#                 1,
#                 2,
#                 4,
#                 27,
#                 0,
#                 23,
#                 3,
#                 0,
#                 2,
#                 1
#             ],
#             "stack": "stack_2147248",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2147248
#         },
#         {
#             "type": "bar",
#             "name": "(-7%, -3%]",
#             "data": [
#                 46,
#                 9,
#                 2,
#                 43,
#                 8,
#                 6,
#                 10,
#                 4,
#                 16,
#                 8,
#                 18,
#                 16,
#                 19,
#                 3,
#                 24,
#                 4,
#                 0,
#                 14,
#                 13
#             ],
#             "stack": "stack_2147248",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2147248
#         },
#         {
#             "type": "bar",
#             "name": "(-3%, 0%)",
#             "data": [
#                 25,
#                 9,
#                 58,
#                 21,
#                 6,
#                 13,
#                 28,
#                 29,
#                 14,
#                 12,
#                 16,
#                 15,
#                 12,
#                 3,
#                 10,
#                 7,
#                 1,
#                 30,
#                 20
#             ],
#             "stack": "stack_2147248",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2147248
#         },
#         {
#             "type": "bar",
#             "name": "[0%, 3%)",
#             "data": [
#                 26,
#                 6,
#                 75,
#                 21,
#                 6,
#                 2,
#                 14,
#                 22,
#                 6,
#                 11,
#                 15,
#                 13,
#                 8,
#                 3,
#                 12,
#                 10,
#                 22,
#                 50,
#                 18
#             ],
#             "stack": "stack_2147248",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2147248
#         },
#         {
#             "type": "bar",
#             "name": "[3%, 7%)",
#             "data": [
#                 18,
#                 15,
#                 48,
#                 17,
#                 7,
#                 5,
#                 8,
#                 13,
#                 10,
#                 10,
#                 15,
#                 9,
#                 8,
#                 8,
#                 7,
#                 5,
#                 23,
#                 26,
#                 13
#             ],
#             "stack": "stack_2147248",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2147248
#         },
#         {
#             "type": "bar",
#             "name": "[7%, 10%)",
#             "data": [
#                 4,
#                 3,
#                 15,
#                 2,
#                 1,
#                 0,
#                 2,
#                 1,
#                 2,
#                 0,
#                 1,
#                 3,
#                 0,
#                 0,
#                 1,
#                 1,
#                 3,
#                 7,
#                 1
#             ],
#             "stack": "stack_2147248",
#             "barCategoryGap": "20%",
#             "label": {

# %%
##制作每日追涨报表
import requests
import time
import tushare as ts
import numpy as np
import os
import traceback
import decimal 

########################################

###挖地兔用户token，该token因积分较低，无法获取部分接口数据，需替换成自己账号的token
###挖地兔注册链接 https://tushare.pro/register?reg=248534

generateExcelFlag = True  ###是否生成表格开关
token = 'db8fbd4b0b8ec4e4f012937c9e1c3a36d5d1b1c6a293eba2d40a4fa3' 

easyMoneyUrl_A = 'http://nuff.eastmoney.com/EM_Finance2015TradeInterface/JS.ashx'
easyMoneyUrl_B = 'http://guba.eastmoney.com/list,'
flashDataUrl = 'http://home.flashdata2.jrj.com.cn/limitStatistic/zt/'
flushUrl_A = 'http://stockpage.10jqka.com.cn/'
head = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'}


excelColumnNum = 12  ###表格列数
peroid = 30          ###交易数据分析周期
duration = 3         ###成交量获取天数               
                                        
currentDate = time.strftime('%Y%m%d',time.localtime(time.time()))
currentDateWithTime = time.strftime('%Y-%m-%d %H点%M分',time.localtime(time.time()))
currentTimeStamp = int(time.time()*1000)

###如果配置文件存在，则获取本地配置的token和配置的秘密网址
try:
    settingFile = open('/data/stock-setting.txt', 'r')
    settings = settingFile.read()
    token = settings.split()[0]
    secretUrl = settings.split()[1]
    settingFile.close()
    
    ###获取秘密网站数据
    response = requests.get(secretUrl)
    text = response.text
    textArray = text.split('\n')
    stockNum = 30             ###股票数量
    stockCodes = []
    for i in range(1, stockNum+1):
        stockText = textArray[i]
        stockCode = stockText.split(',')[1]
        stockCodes.append(str(stockCode))
except IOError:
    print('File is not accessible.')
    stockCodes = ['000159', '600345', '300663', '600831', '000990', '002307', '300536', '300171', '000993', '002473', '000788', '600232', '603169', '000905', '000610', '600722', '600072', '600800', '000156', '600199']
    stockNum = len(stockCodes)  
    
pro = ts.pro_api(token)
################## 函数 ####################

def getCodeWithSuffix(code):
    if code[0] == '6':
        return code + '.SH'
    else: 
        return code + '.SZ'
    
def formatVolume(var):
    if (var < 10000):
        return round(var/10000, 1)
    else: 
        return int(round(var/10000))

def calculateLimitPrice(price):
    lowRate = 0.9
    highRate = 1.1
    smallNum = 0.00001
    low = round(price*lowRate + smallNum, 2)
    high = round(price*highRate + smallNum, 2)
    return [low, high]

def isLimitHighPrice(close, pre_close):
    limitHighPrice = calculateLimitPrice(pre_close)
    if limitHighPrice[1] == close:
        return 1
    else:
        return 0
    
def getCodeWithNumSuffix(code):
    if code[0] == '6':
        return code + '1'
    else: 
        return code + '2'
    
def constructUrl_A(code, url):
    code = getCodeWithNumSuffix(code)
    return url + '?id=' + code

def constructUrl_B(code, url):
    return url + code + '.html'


def removeQuotationMarks(var):
    return var.split("\"",)[1]


    ###当卖单全空展示买一量，否则展示-1*卖一量
def finalOrder(code):
    finalOrderUrl = constructUrl_A(code, easyMoneyUrl_A)
    response = requests.get(finalOrderUrl)
    text = response.text  
    priceAmount = text.split(',')[4:24]
    for i in range(0, len(priceAmount)):
        tmp = priceAmount[i]
        priceAmount[i] = removeQuotationMarks(tmp)
    if priceAmount[5] == '-':
        return priceAmount[10]
    else:
        return '-' + priceAmount[15]      
    
def getDailyViewRank(code):
    finalGuBaUrl = constructUrl_B(code, easyMoneyUrl_B)
    response = requests.get(finalGuBaUrl)
    tmp1 = response.text.split('<em class="ran_num">')
    if len(tmp1) == 1:
        return 'not found'
    else:
        tmp2 = tmp1[1].split('</em> 名</span>')
        return tmp2[0]
    
def getLimitUpStockInfo(date, url):
    flashDataUrl = url + date + '.js'
    response = requests.get(flashDataUrl)
    (a,b,c) = response.text.partition(",\"Data\":[[")
    (stockInfoStr,e,f) = c.partition("]]};")
    tmpStockInfo = stockInfoStr.split("],[")
    stockInfo = []
    for i in range(0, len(tmpStockInfo)):  
        tmp = []
        singleStock = tmpStockInfo[i].split(',')
        stockInfo.append(singleStock) 
    return stockInfo

def mkdir(path):
    path = path.strip()
    path = path.rstrip("\\")
    isExists = os.path.exists(path)
    if not isExists:
        os.makedirs(path) 
        print(path +' 创建成功')
        return True
    else:
        print(path +' 目录已存在')
        return False
                     
###获取交易日历
calendar = pro.trade_cal(is_open = 1, end_date = currentDate, fields = 'cal_date')
calendarCut = calendar[-peroid:]
startDate = calendarCut.iloc[0, 0]
endDate = calendarCut.iloc[peroid-1, 0]

###当日涨停股记录
limitUPMap = {}
stockInfo = getLimitUpStockInfo(endDate, flashDataUrl)
for i in range(0, len(stockInfo)):
    code = removeQuotationMarks(stockInfo[i][0])
    limitUpTime = removeQuotationMarks(stockInfo[i][2])
    limitUPMap[code] = limitUpTime

###获取交易数据
result = []
for i in range(0, len(stockCodes)): 
    try:
        rowResult = [0]*excelColumnNum
        code = stockCodes[i]
        codeWithSuffix = getCodeWithSuffix(code)
        
        ###获取股票名称
        nameHistory = pro.namechange(ts_code = codeWithSuffix, fields='name')
        name = nameHistory.iloc[0, 0]
        
        
        ###获取成交量
        recentTrade = pro.daily(ts_code = codeWithSuffix, start_date=startDate, end_date=endDate, fields = 'trade_date, close, pre_close, vol')
        recentVolume = ''
        for j in range(0, duration):
            if j == 0:
                recentVolume =  str(formatVolume(recentTrade.iloc[j, 3]))
            elif j < recentTrade.shape[0]:  ###考虑复牌情况
                recentVolume = str(formatVolume(recentTrade.iloc[j, 3])) + '-' + recentVolume  
        recentVolume = '[' + recentVolume + ']'
 
            
        ###获取东财当日浏览排名
        viewRank = getDailyViewRank(code)
        
        ###封板时间
        limitUpTime = '-'
        if code in limitUPMap:
            limitUpTime = limitUPMap[code]
            
        ###获取换手率、总市值、股票单价  
        dailyInfo = pro.daily_basic(ts_code = codeWithSuffix, trade_date = endDate, fields = 'turnover_rate_f, circ_mv, close')
        #print(dailyInfo)
        closePrice = dailyInfo.iloc[0, 0]
        turnoverRate = str(round(dailyInfo.iloc[0, 1], 2)) + '%'
        circ_mv = str(round(dailyInfo.iloc[0, 2]/10000, 2)) + '亿'  
            
        ###获取连板数
        limitCount = peroid
        for j in range(0, len(recentTrade)):
            if isLimitHighPrice(recentTrade.iloc[j, 1], recentTrade.iloc[j, 2]) == 0:
                limitCount = j
                if j > 0 and limitUpTime == '-':
                    limitUpTime = '一字板'
                break
    
        ###获取封单数 当股票收盘未涨停时返回空
        orderNum = '-'
        if limitCount > 0:
            orderNum = finalOrder(code)     
        
        ###获取股票题材
        theme = '-'
        response = requests.get(flushUrl_A + code + '/', headers = head)
        text = response.text
        tmp1 = text.split('<dt>涉及概念：</dt>\n\t\t\t\t\t<dd title=\"')
        if len(tmp1) > 1:   
            tmp2 = tmp1[1].split('\">')
            theme = tmp2[0]
            
        ###数据转配
        rowResult[0] = i+1
        rowResult[1] = str(code)
        rowResult[2] = name
        rowResult[3] = viewRank
        rowResult[4] = recentVolume
        rowResult[5] = turnoverRate
        rowResult[6] = closePrice
        rowResult[7] = circ_mv
        rowResult[8] = limitCount
        rowResult[9] = limitUpTime
        rowResult[10] = orderNum
        rowResult[11] = theme
        result.append(rowResult)
        
    except BaseException as e:
        print('处理code=' + code + '时出现异常', e)
        traceback.print_exc()
             
print(result)

if generateExcelFlag:
    directory = '/data/stock/'
    mkdir(directory)
    fileName = '[BestStock]' + str(currentDateWithTime) + '.xls'
    columnName = '编号\t股票代码\t股票名称\t热度排名\t三日成交量(万手)\t换手率\t收盘价\t流通市值\t连板数\t封板时间\t封板单\t题材\n'
    output = open(directory + fileName,'w',encoding='gbk')
    output.write(columnName)
    for i in range(len(result)):
        for j in range(len(result[i])):
            output.write(str(result[i][j]))
            output.write('\t')  
        output.write('\n')       
    output.close()
# Out:
# [[1, '002496', '辉丰股份', '55', '[11-12-35]', '4.37%', 4.48, '42.56亿', 4, '一字板', '365203', '摘帽，乡村振兴，参股民营银行，互联网+，农村电商，电子商务，草甘膦'], [2, '002748', '世龙实业', '1001', '[1-31-15]', '18.43%', 13.17, '31.61亿', 4, '09:38:48', '29619', '分散染料'], [3, '300378', '鼎捷软件', '370', '[36-22-42]', '30.55%', 26.04, '68.33亿', 6, '10:26:09', '146682', '透明工厂，人工智能，工业互联网，工业4.0，大数据'], [4, '300194', '福安药业', '62', '[112-61-94]', '16.59%', 8.03, '48.16亿', 8, '14:55:21', '-8121', '工业大麻，商誉减值'], [5, '600517', '置信电气', '117', '[1-2-3]', '0.52%', 9.36, '116.49亿', 7, '一字板', '448357', '节能环保，特高压，央企国资改革，融资融券，智能电网'], [6, '002099', '海翔药业', '111', '[7-144-205]', '22.43%', 10.69, '172.1亿', 4, '11:04:12', '89913', '年报预增，融资融券，深股通，分散染料，医疗改革'], [7, '000723', '美锦能源', '2', '[199-276-299]', '32.92%', 16.44, '177.76亿', 0, '-', '-', '氢能源，年报预增，燃料电池，天然气，深股通，新能源汽车，石墨电极，机器人概念'], [8, '300435', '中泰股份', '2073', '[12-6-5]', '6.02%', 17.34, '20.55亿', 3, '一字板', '22974', '氢能源，一带一路，燃料电池，煤化工，天然气，节能环保'], [9, '002703', '浙江世宝', '270', '[63-53-87]', '42.39%', 7.78, '43.03亿', 0, '-', '-', '无人驾驶，深股通'], [10, '000927', '一汽夏利', '41', '[2-100-77]', '14.77%', 6.22, '99.22亿', 1, '10:00:42', '44161', '央企国资改革，新能源汽车'], [11, '600150', '中国船舶', '17', '[0.4-0.7-1]', '0.21%', 27.02, '372.37亿', 3, '一字板', '148461', '摘帽，军民融合，中字头股票，国产航母，一带一路，风电，高端装备，军工，海工装备'], [12, '600389', '江山股份', '850', '[0.9-30-25]', '20.81%', 25.97, '77.13亿', 0, '-', '-', '股权转让，乡村振兴，融资融券，草甘膦，金改'], [13, '000958', '东方能源', '42', '[88-1-1]', '0.16%', 6.52, '71.67亿', 3, '一字板', '495453', '央企国资改革，太阳能，风电，雄安新区，光伏概念，京津冀一体化'], [14, '603709', '中源家居', '2683', '[2-3-3]', '13.02%', 44.8, '8.96亿', 0, '-', '-', '养老概念'], [15, '002347', '泰尔股份', '632', '[40-30-27]', '10.43%', 6.77, '21.6亿', 3, '一字板', '80231', '透明工厂，创投，锂电池，新能源汽车，工业4.0，3D打印，机器人概念'], [16, '300110', '华仁药业', '20', '[141-175-177]', '30.94%', 8.15, '96.01亿', 0, '-', '-', '工业大麻'], [17, '002210', '飞马国际', '29', '[267-278-261]', '46.87%', 6.15, '100.25亿', 0, '-', '-', '粤港澳大湾区，国资驰援，融资融券，固废处理，节能环保，深股通，上海自贸区，电子商务'], [18, '000514', '渝开发', '695', '[48-62-78]', '25.08%', 6.82, '57.55亿', 3, '13:16:21', '68096', '债转股，金改'], [19, '603998', '方盛制药', '390', '[14-1-2]', '0.88%', 10.37, '44.09亿', 3, '一字板', '232511', ''], [20, '300266', '兴源环境', '133', '[112-188-218]', '24.76%', 6.8, '99.42亿', 3, '14:49:21', '22057', '国资驰援，深股通，PPP概念，美丽中国，污水处理，节能环保'], [21, '300275', '梅安森', '1123', '[4-0.5-1]', '0.99%', 13.32, '15.66亿', 3, '一字板', '60123', '透明工厂，乡村振兴，互联网+，PPP概念，污水处理，智慧城市，物联网，工业4.0'], [22, '603823', '百合花', '686', '[4-22-22]', '37.72%', 31.13, '21.9亿', 0, '-', '-', ''], [23, '600422', '昆药集团', '72', '[100-129-126]', '27.26%', 14.33, '108.72亿', 0, '-', '-', '工业大麻，独角兽概念，沪股通，融资融券'], [24, '600163', '中闽能源', '548', '[1-48-62]', '13.82%', 5.27, '52.67亿', 1, '14:51:59', '7131', '新能源汽车，债转股，光伏概念，风电，电力改革'], [25, '603079', '圣达生物', '1740', '[0.8-8-6]', '15.24%', 32.65, '11.92亿', 0, '-', '-', ''], [26, '300174', '元力股份', '814', '[3-17-9]', '9.57%', 29.39, '64.98亿', 0, '-', '-', '年报预增，网络游戏，手机游戏，PM2.5'], [27, '000565', '渝三峡A', '1092', '[37-34-47]', '18.13%', 7.88, '34.17亿', 1, '14:53:48', '20126', '融资融券，石墨烯，金改'], [28, '300099', '精准信息', '18', '[14-146-187]', '62.63%', 11.3, '44.26亿', 0, '-', '-', '特高压，芯片概念，燃料电池，区块链，空铁WIFI，军民融合，军工'], [29, '603085', '天成自控', '1360', '[43-47-42]', '41.9%', 12.37, '18.24亿', 0, '-', '-', '工业4.0'], [30, '600555', '海航创新', '900', '[45-112-89]', '13.49%', 4.07, '39.62亿', 2, '09:50:01', '71142', '体育产业，赛马概念，土地流转']]
# /data/stock/ 目录已存在

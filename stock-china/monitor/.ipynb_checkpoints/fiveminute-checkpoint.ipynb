# %%
## 从导出的表格中获取同花顺最近半年涨停超过N次的非ST股票数据
## 条件：非st股票 半年内涨停超过6次
import xlrd
data = xlrd.open_workbook('/data/stock_new/half_year_good_stocks.xlsx')
table = data.sheets()[0]
code_list = table.col_values(0)[1::]
codes = [code.split('.')[0] for code in code_list]
print(codes)

# %%
## 获取东方财富5分钟成交量,该9.35的数据未计算开盘竞价的价格变动与成交量
# 5分钟价格：[open, close, high, low]
import requests
import json 
from pandas import DataFrame
import pandas as pd
import numpy as np
import time
import threading
import sys 
sys.path.append('/Users/flee/myspace/utils') 
import fmail

DAY_NUM = 5
DAILY_DIVISION_COUNT = 48
LAST_INDEX = 1439
LOW_PRICE_COLUMN_INDEX = 2
VOL_COLUMN_INDEX = 3


def isSuitableTime(lastDateStr):
    lastTime = time.strptime(lastDateStr, "%Y-%m-%d %H:%M")
    lastTimeStamp = int(time.mktime(lastTime))
    currentTimeStamp = int(time.time())
    accept_diff = 900 #最近十五分钟
    return currentTimeStamp - lastTimeStamp < accept_diff

def getSuffixCode(code):
    if code[0] == '6':
        return code + '1'
    else: 
        return code + '2'
    
def getMean(vols):
    return np.mean(np.array(vols))

def getMin(closes):
    return np.min(np.array(closes))

def isLowPriceDoubleVol(low, vol, min_close, mean_vol):
    if low < min_close and vol > 3 * mean_vol:
        return True
    else:
        return False
    
# ## 最低价触及最近5天5分钟收盘价新低，且成交倍量
# ## 判断最近两个5分钟的主要防御东财数据更新不及时
def isTargetStock(code_id):
    easy_url = 'http://pdfm.eastmoney.com/EM_UBG_PDTI_Fast/api/js?rtntype=5&token=4f1862fc3b5e77c150a2b985b12db0fd&type=m5k&authorityType=fa&id='
    final_url = easy_url + getSuffixCode(code_id)
    response = requests.get(final_url)
    data_str = response.text.split('(')[-1].split(')')[0]
    data = json.loads(data_str)['data']
    if not isSuitableTime(data[-1].split(',')[0]):
        return False    
    time_list = []
    close_list = []
    low_list = []
    vol_list = []
    for stock_tick in data:
        tick_array = stock_tick.split(',')
        time_list.append(tick_array[0])
        close_list.append(float(tick_array[2]))
        low_list.append(float(tick_array[4]))
        vol_list.append(int(tick_array[6])/1000)
    mean_vol = getMean(vol_list)
    closes = close_list[-DAY_NUM*DAILY_DIVISION_COUNT:]
    min_close = getMin(closes)
    return isLowPriceDoubleVol(low_list[-1], vol_list[-1], min_close, mean_vol) or isLowPriceDoubleVol(low_list[-2], vol_list[-2], min_close, mean_vol)  
    return False

def fetchResult(codes):
    result_codes = []
    failed_codes = []
    start = time.time()
    for code in codes:
        try:
            if isTargetStock(code):
                result_codes.append(code)
        except BaseException as e:
            failed_codes.append(code)
            pass
        continue
    elapsed = time.time() - start
    print('计算' + str(len(codes)) + '个股票, 共花费' + str(elapsed) + '秒')
    if failed_codes:
        print('失败股票codes=')
        print(failed_codes)
    return result_codes


lock = threading.Lock()
result = []
class MultiThreadingCal(threading.Thread):
    def __init__(self, codes):
        super(MultiThreadingCal, self).__init__()
        self.codes = codes
    def run(self):
        global result
        tmpResult = fetchResult(self.codes)
        with lock:
            result = result + tmpResult 
            
def listSplit(listTemp, n):
    for i in range(0, n):
        yield listTemp[i::n]
        
def cal_main():
    start = time.time()
    localtime = time.localtime(start)
    strTime = time.strftime("%Y-%m-%d %H:%M:%S", localtime)
    print('开始时间为 ' + strTime)
    threads = []
    # 创建新子线程
    codes_array = listSplit(codes, 5)
    for single_codes in codes_array:
        subThread = MultiThreadingCal(single_codes)
        subThread.start()
        threads.append(subThread)
    # 等待所有线程完成
    for t in threads:
        t.join()
    global result
    print(result)
    
    ##发邮件 用守护线程包裹，作为邮件发送超时的一种防御(但会导致守护线程一直结束不了)
    if result:
        topic = '【股票】低吸买点'
        text = '以下股票出现低吸买点\n' + str(result)
        t = threading.Thread(target=fmail.mail, args = (topic, text))
        t.setDaemon(True)
        t.start()
        t.join(2)
    with lock:
        result = []
    end = time.time()
    elapsed = end - start
    localtime = time.localtime(end)
    strTime = time.strftime("%Y-%m-%d %H:%M:%S", localtime)
    print('结束时间为  ' + strTime)
    print('计算' + str(len(codes)) + '个股票, 共花费' + str(elapsed) + '秒')
    print('Exiting cal_main Thread')
print('done')
# Out:
# done

# %%
import datetime
import time
from apscheduler.schedulers.background import BackgroundScheduler

def timedTask():
    print(datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S.%f")[:-3])
    
# 创建后台执行的 schedulers
scheduler = BackgroundScheduler()  
# 添加调度任务
#     scheduler.add_job(cal_main, 'cron', day_of_week = '0-4', hour = '9-11, 13-15' minute = '*/5')
scheduler.add_job(cal_main, 'cron', minute = '*/5')
# 启动调度任务
scheduler.start()
print('start')
# Out:
# start
# 开始时间为 2019-07-22 13:40:00
# 计算68个股票, 共花费33.992660999298096秒
# 计算68个股票, 共花费50.729626178741455秒
# 计算68个股票, 共花费50.8249728679657秒
# 计算68个股票, 共花费62.92960476875305秒
# 计算68个股票, 共花费74.82668805122375秒
# []
# 结束时间为  2019-07-22 13:41:14
# 计算340个股票, 共花费74.83018779754639秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 13:45:00
# 计算68个股票, 共花费108.09299826622009秒
# 计算68个股票, 共花费112.12552809715271秒
# 计算68个股票, 共花费126.8714599609375秒
# 计算68个股票, 共花费155.64341616630554秒
# 计算68个股票, 共花费189.27653908729553秒
# []
# 结束时间为  2019-07-22 13:48:09
# 计算340个股票, 共花费189.28499507904053秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 13:50:00
# 计算68个股票, 共花费99.40045499801636秒
# 计算68个股票, 共花费101.75631213188171秒
# 计算68个股票, 共花费106.50848579406738秒
# 计算68个股票, 共花费131.55080103874207秒
# 计算68个股票, 共花费133.6071286201477秒
# []
# 结束时间为  2019-07-22 13:52:13
# 计算340个股票, 共花费133.61188292503357秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 13:55:00
# 计算68个股票, 共花费64.36568188667297秒
# 计算68个股票, 共花费65.14410066604614秒
# 计算68个股票, 共花费66.66910791397095秒
# 计算68个股票, 共花费80.74910688400269秒
# 计算68个股票, 共花费96.59396886825562秒
# []
# 结束时间为  2019-07-22 13:56:36
# 计算340个股票, 共花费96.60063171386719秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:00:00
# 计算68个股票, 共花费58.04651713371277秒
# 计算68个股票, 共花费81.60384011268616秒
# 计算68个股票, 共花费84.18726205825806秒
# 计算68个股票, 共花费88.36549496650696秒
# 计算68个股票, 共花费91.07572412490845秒
# []
# 结束时间为  2019-07-22 14:01:31
# 计算340个股票, 共花费91.08533096313477秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:05:00
# 计算68个股票, 共花费225.4747121334076秒
# 失败股票codes=
# ['600371', '601608', '603317', '000590', '002437']
# 计算68个股票, 共花费225.57323598861694秒
# 失败股票codes=
# ['603701', '000785', '002835', '300167', '300279']
# 计算68个股票, 共花费230.74874806404114秒
# 失败股票codes=
# ['600928', '603998', '002166', '002958', '300176']
# 计算68个股票, 共花费248.12058091163635秒
# 失败股票codes=
# ['300542', '600844', '601700', '603681', '000958']
# 计算68个股票, 共花费255.84233403205872秒
# 失败股票codes=
# ['002567', '300099', '300769', '600331', '600536']
# []
# 结束时间为  2019-07-22 14:09:15
# 计算340个股票, 共花费255.85009789466858秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:10:00
# 计算68个股票, 共花费37.393563985824585秒
# 计算68个股票, 共花费38.63405990600586秒
# 计算68个股票, 共花费40.04176378250122秒
# 计算68个股票, 共花费71.19913005828857秒
# 计算68个股票, 共花费77.017019033432秒
# []
# 结束时间为  2019-07-22 14:11:17
# 计算340个股票, 共花费77.02871179580688秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:15:00
# 计算68个股票, 共花费114.99991989135742秒
# 失败股票codes=
# ['300772']
# 计算68个股票, 共花费117.65338397026062秒
# 失败股票codes=
# ['002953']
# 计算68个股票, 共花费123.31647515296936秒
# 失败股票codes=
# ['300313']
# 计算68个股票, 共花费140.63286089897156秒
# 失败股票codes=
# ['002481']
# 计算68个股票, 共花费180.539324760437秒
# 失败股票codes=
# ['603000']
# ['603332']
# 邮件发送成功
# 结束时间为  2019-07-22 14:18:02
# 计算340个股票, 共花费182.44931769371033秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:20:00
# 计算68个股票, 共花费55.91378092765808秒
# 计算68个股票, 共花费62.614938259124756秒
# 计算68个股票, 共花费68.2758560180664秒
# 计算68个股票, 共花费82.29083681106567秒
# 计算68个股票, 共花费86.36312294006348秒
# ['603332']
# 结束时间为  2019-07-22 14:21:28
# 计算340个股票, 共花费88.37079429626465秒
# Exiting cal_main Thread
# 邮件发送成功
# 开始时间为 2019-07-22 14:25:00
# 计算68个股票, 共花费57.350472927093506秒
# 计算68个股票, 共花费59.19763493537903秒
# 计算68个股票, 共花费59.314955949783325秒
# 计算68个股票, 共花费75.68279910087585秒
# 计算68个股票, 共花费98.32919311523438秒
# []
# 结束时间为  2019-07-22 14:26:38
# 计算340个股票, 共花费98.33546304702759秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:30:00
# 计算68个股票, 共花费41.0454363822937秒
# 计算68个股票, 共花费41.0781466960907秒
# 计算68个股票, 共花费41.134154081344604秒
# 计算68个股票, 共花费44.88453006744385秒
# 计算68个股票, 共花费49.08210897445679秒
# ['600800']
# 结束时间为  2019-07-22 14:30:51
# 计算340个股票, 共花费51.096275091171265秒
# Exiting cal_main Thread
# 邮件发送成功
# 开始时间为 2019-07-22 14:35:00
# 计算68个股票, 共花费39.43272590637207秒
# 计算68个股票, 共花费45.522144079208374秒
# 计算68个股票, 共花费48.39493203163147秒
# 计算68个股票, 共花费53.132787227630615秒
# 计算68个股票, 共花费62.43009877204895秒
# []
# 结束时间为  2019-07-22 14:36:02
# 计算340个股票, 共花费62.43546390533447秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:40:00
# 计算68个股票, 共花费68.44503784179688秒
# 计算68个股票, 共花费68.64232587814331秒
# 计算68个股票, 共花费77.63505911827087秒
# 计算68个股票, 共花费78.01401805877686秒
# 计算68个股票, 共花费81.97596406936646秒
# []
# 结束时间为  2019-07-22 14:41:21
# 计算340个股票, 共花费81.98458790779114秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:45:00
# 计算68个股票, 共花费62.28745484352112秒
# 计算68个股票, 共花费70.55237412452698秒
# 计算68个股票, 共花费73.06851100921631秒
# 计算68个股票, 共花费75.98528409004211秒
# 计算68个股票, 共花费114.39356899261475秒
# []
# 结束时间为  2019-07-22 14:46:54
# 计算340个股票, 共花费114.40188694000244秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:50:00
# 计算68个股票, 共花费47.826277017593384秒
# 计算68个股票, 共花费49.251803159713745秒
# 计算68个股票, 共花费65.8210608959198秒
# 计算68个股票, 共花费81.33823585510254秒
# 计算68个股票, 共花费105.69332885742188秒
# ['300594']
# 邮件发送成功
# 结束时间为  2019-07-22 14:51:46
# 计算340个股票, 共花费106.19697403907776秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 14:55:00
# 计算68个股票, 共花费38.51735806465149秒
# 计算68个股票, 共花费39.61587476730347秒
# 计算68个股票, 共花费42.28789520263672秒
# 计算68个股票, 共花费48.10836577415466秒
# 计算68个股票, 共花费63.05910897254944秒
# ['300594', '002458']
# 邮件发送成功
# 结束时间为  2019-07-22 14:56:03
# 计算340个股票, 共花费63.61482310295105秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 15:00:00
# 计算68个股票, 共花费73.09422183036804秒
# 计算68个股票, 共花费82.27235507965088秒
# 计算68个股票, 共花费82.36660504341125秒
# 计算68个股票, 共花费85.10178518295288秒
# 计算68个股票, 共花费98.4873058795929秒
# ['600775', '300594', '601698']
# 结束时间为  2019-07-22 15:01:40
# 计算340个股票, 共花费100.50765013694763秒
# Exiting cal_main Thread
# 邮件发送成功
# 开始时间为 2019-07-22 15:05:00
# 计算68个股票, 共花费66.78567123413086秒
# 计算68个股票, 共花费76.8110339641571秒
# 计算68个股票, 共花费93.23343420028687秒
# 计算68个股票, 共花费98.4354259967804秒
# 计算68个股票, 共花费103.56571006774902秒
# ['300594', '600775']
# 结束时间为  2019-07-22 15:06:45
# 计算340个股票, 共花费105.58697509765625秒
# Exiting cal_main Thread
# 邮件发送成功
# 开始时间为 2019-07-22 15:10:00
# 计算68个股票, 共花费42.986170053482056秒
# 计算68个股票, 共花费62.33829998970032秒
# 计算68个股票, 共花费62.40865993499756秒
# 计算68个股票, 共花费95.28188991546631秒
# 计算68个股票, 共花费101.42597031593323秒
# []
# 结束时间为  2019-07-22 15:11:41
# 计算340个股票, 共花费101.43655395507812秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 15:15:00
# 计算68个股票, 共花费53.774091958999634秒
# 计算68个股票, 共花费63.78351712226868秒
# 计算68个股票, 共花费81.38818979263306秒
# 计算68个股票, 共花费88.45706796646118秒
# 计算68个股票, 共花费132.38357305526733秒
# []
# 结束时间为  2019-07-22 15:17:12
# 计算340个股票, 共花费132.38497400283813秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 15:20:00
# 计算68个股票, 共花费96.98389410972595秒
# 失败股票codes=
# ['000862']
# 计算68个股票, 共花费98.04056406021118秒
# 失败股票codes=
# ['300152']
# 计算68个股票, 共花费114.60102891921997秒
# 失败股票codes=
# ['300782']
# 计算68个股票, 共花费164.8497109413147秒
# 失败股票codes=
# ['300762']
# 计算68个股票, 共花费177.72479104995728秒
# 失败股票codes=
# ['002057', '300780']
# []
# 结束时间为  2019-07-22 15:22:57
# 计算340个股票, 共花费177.74722623825073秒
# Exiting cal_main Thread
# 开始时间为 2019-07-22 15:25:00
# 计算68个股票, 共花费68.69212484359741秒
# 计算68个股票, 共花费83.37250399589539秒

# %%
import tushare as ts
import sys
sys.path.append('/Users/flee/myspace/utils')
import fshare

token = fshare.getToken()
pro = ts.pro_api(token)
pd = pro.moneyflow_hsgt(start_date = '20150101', end_date = '20150806')
print(pd)
# Out:
#     trade_date  ggt_ss ggt_sz       hgt   sgt  north_money  south_money
# 0     20150806   178.0   None    348.00  None       348.00        178.0
# 1     20150805   174.0   None     74.00  None        74.00        174.0
# 2     20150804   406.0   None   -274.00  None      -274.00        406.0
# 3     20150803   127.0   None  -2137.00  None     -2137.00        127.0
# 4     20150731    60.0   None    527.00  None       527.00         60.0
# 5     20150730   202.0   None    -61.00  None       -61.00        202.0
# 6     20150729   729.0   None   -487.00  None      -487.00        729.0
# 7     20150728   304.0   None   2665.00  None      2665.00        304.0
# 8     20150727   102.0   None   -148.00  None      -148.00        102.0
# 9     20150724   507.0   None      9.00  None         9.00        507.0
# 10    20150723   434.0   None    494.00  None       494.00        434.0
# 11    20150722   601.0   None   -434.00  None      -434.00        601.0
# ...
